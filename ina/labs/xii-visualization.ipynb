# %% [markdown]
# ### Introduction to Network Analysis 2024/25 (xii)

# %% [markdown]
# # Pegs and bands, wiring diagrams vs block models

# %% [markdown]
# ### I. Board with pegs and bands
#
# You are given a handmade network with different planted structures (e.g., community or core-periphery structure, hub and spokes arrangement). The network is given in an edge list format, with edges within each planted structure coded with the same color and edges between different structures coded with white color.
#
# | | | | | |
# | :---: | :---: | :---: | :---: | :---: |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **1 — 10** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(255,255,255)">&nbsp;</span> **1 — 20** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **1 — 25** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **2 — 9** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **2 — 20** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(255,255,255)">&nbsp;</span> **2 — 33** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **3 — 18** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **3 — 29** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **4 — 5** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **4 — 8** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **4 — 13** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **4 — 15** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(255,255,255)">&nbsp;</span> **4 — 25** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **6 — 7** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **6 — 32** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **6 — 34** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **7 — 10** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **7 — 32** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **7 — 34** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **8 — 16** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **8 — 17** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **8 — 27** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **8 — 31** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **9 — 24** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **9 — 28** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **10 — 25** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **10 — 34** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **11 — 12** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **11 — 33** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **12 — 14** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **12 — 19** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **12 — 30** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **14 — 19** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **14 — 21** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **14 — 30** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **16 — 23** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **17 — 23** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **18 — 28** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **19 — 30** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **19 — 33** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **20 — 24** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **22 — 30** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(255,255,255)">&nbsp;</span> **23 — 26** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **23 — 27** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(155,187,90)">&nbsp;</span> **23 — 31** |
# | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **24 — 29** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(121,121,121)">&nbsp;</span> **26 — 30** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(80,131,189)">&nbsp;</span> **28 — 29** | <span style="display:inline-block;width:20px;height:20px;border-style:solid;border-width:2px;background-color:rgb(106,40,134)">&nbsp;</span> **32 — 34**
#
# Your task is to first reveal the structure of the network without using a computer or other electronic device.

# %% [markdown]
# 1. **(work)** You can use a board with numbered wooden pegs and rubber bands of different color. These should serve as network nodes and edges, respectively. To simulate force-directed layout of a network, rubber bands will take care of the attractive forces between the linked nodes. You should, however, simulate the repulsive forces between the nodes on your own.
#
# 	<p align="center">
# 		<img src="data:image/jpeg;base64,..." />
# 	</p>

# %% [markdown]
# 2. **(work)** Alternatively, you can use a whiteboard and markers of different color.

# %% [markdown]
# 3. **(code)** Finally, browse your network library for implementations of network layout algorithms and methods for network visualization. Try to clearly visualize the network with a wiring diagram.

# %%
# your code here

# %% [markdown]
# ### II. Wiring diagrams vs block models
#
# You are given six real networks with less than $200$ nodes.
#
# + Zachary karate club network ([karate_club.net](http://lovro.fri.uni-lj.si/ina/nets/karate_club.net))
# + Davis southern women network ([southern_women.net](http://lovro.fri.uni-lj.si/ina/nets/southern_women.net))
# + Lusseau bottlenose dolphins network ([dolphins.net](http://lovro.fri.uni-lj.si/ina/nets/dolphins.net))
# + US college football network ([american_football.net](http://lovro.fri.uni-lj.si/ina/nets/american_football.net))
# + Slovenian highways network from $2010$ ([highways.net](http://lovro.fri.uni-lj.si/ina/nets/highways.net))
# + Little Rock Lake food web ([foodweb_littlerock.net](http://lovro.fri.uni-lj.si/ina/nets/foodweb_littlerock.net))

# %% [markdown]
# 1. **(code)** Browse your network library for implementations of network layout algorithms and methods for network visualization. Try to clearly visualize the networks with a wiring diagram produced by different layout algorithms. Furthermore, you can use node sizes to show their centrality and node colors to show network community, core-periphery or other structure.

# %%
# your code here

# %% [markdown]
# ![](http://lovro.fri.uni-lj.si/ina/nets/foodweb_littlerock.kamada_kawai.pdf)

# %% [markdown]
# 2. **(code)** Visualize the networks also with a block model, where you plot the network adjacency matrix with nodes ordered according to their group affiliation (e.g., community structure).

# %%
# your code here

# %% [markdown]
# ![](http://lovro.fri.uni-lj.si/ina/nets/american_football.blocks.pdf)
